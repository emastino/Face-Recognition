# %%
# Successfully uninstalled numpy-1.19.4
# Successfully installed numpy-1.19.3 ( needed this version of numpy for it to work)
# import numpy
import numpy as np

# import open source coputer vision library
import cv2

import pickle

# %matplotlib inline 

#import matplotlib.pyplot
import matplotlib.pyplot as plt

# import matplotlib.image
import matplotlib.image as mpimg

# %%
# cascade only for front of face. Profile of face will hardly get recognized!!
face_cascade = cv2.CascadeClassifier('cascades/data/haarcascade_frontalface_alt2.xml')
# recognizer
recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read("trainner.yml")

labels = {"person_name": 1}
with open("labels.pickle",'rb') as f:
    og_labels = pickle.load(f)
    labels = {v:k for k, v in og_labels.items()}

    
print(labels)
# video capture with primary webcam
cap = cv2.VideoCapture(0)
# cap.release()
# cv2.destroyAllWindows()
# Out:
# {0: 'Antonellu', 1: 'Delilah', 2: 'Emi', 3: 'Gianpi', 4: 'Madre', 5: 'Vito'}

# %%
# video loop
while True:
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor =1.5, minNeighbors =5)
    
    for (x,y,w,h) in faces:
#         print(x,y,w,h)
        
        # region of interest in gray from y to y+h and x to x+w
        roi_gray = gray[y:y+h,x:x+w]
        
        # region of interest color from y to y+h and x to x+w
        roi_color = frame[y:y+h,x:x+w]
        
        #recognizer
        id_ ,conf = recognizer.predict(roi_gray)
        
        print(labels[id_], conf)
        # save image
        img_item = "11.jpg" # image name
        cv2.imwrite(img_item,roi_color) # save image
        
        # make box
        boxColor = (25,200, 50) # BGR why!? from 0-255
        boxLineWidth = 3
        cv2.rectangle(frame, (x,y), (x+w,y+h), boxColor, boxLineWidth)
        
        # only put name if confident in prediction
        if conf >55:
            # add text to box
            font = cv2.FONT_ITALIC
            fontScale = 1
            cv2.putText(frame, labels[id_], (x+15,y+h-15), font,  
                       fontScale, boxColor, boxLineWidth, cv2.LINE_AA)
        
    cv2.imshow('frame', frame)
    
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Delilah 42.94662483578064
# Delilah 44.208882259291734
# Delilah 43.60088079183899
# Delilah 42.401408511060716
# Delilah 42.401408511060716
# Delilah 40.912658686329934
# Delilah 41.236966263986595
# Delilah 40.59799003513684
# Delilah 39.17453459138081
# Delilah 39.17453459138081
# Delilah 39.111347612226844
# Delilah 40.18644091679924
# Delilah 40.18644091679924
# Delilah 40.078792565704
# Delilah 38.85858152601161
# Delilah 38.209522400968005
# Delilah 38.209522400968005
# Delilah 38.25591572633508
# Delilah 39.2891414022303
# Delilah 39.2891414022303
# Delilah 38.51751913885436
# Delilah 38.942503035929754
# Delilah 37.306635809039136
# Delilah 37.306635809039136
# Delilah 38.448880585801945
# Delilah 37.5057101151541
# Delilah 39.92619316450739
# Delilah 39.92619316450739
# Delilah 37.823168181450015
# Delilah 38.02233316085303
# Delilah 38.258512378804596
# Delilah 38.258512378804596
# Delilah 38.56701779915522
# Delilah 38.77444694909187
# Delilah 38.158376314316506
# Delilah 38.158376314316506
# Delilah 38.35735563608832
# Delilah 38.11067683989321
# Delilah 38.546370130101785
# Delilah 38.546370130101785
# Delilah 38.47486808831668
# Delilah 39.16307165986293
# Delilah 38.59389518344384
# Delilah 38.59389518344384
# Delilah 38.83744486176241
# Delilah 38.957058599087794
# Delilah 38.29543304793568
# Delilah 38.29543304793568
# Delilah 38.6734298839289
# Delilah 38.40466113784379
# Delilah 38.96497662712029
# Delilah 38.96497662712029
# Delilah 39.01686912733527
# Delilah 38.745584553578375
# Delilah 39.36013068367785
# Delilah 38.356484858297215
# Delilah 38.356484858297215
# Delilah 38.14148596499171
# Delilah 39.248479796205615
# Delilah 39.08062928671701
# Delilah 39.08062928671701
# Delilah 38.82003181547744
# Delilah 38.9926510820058
# Delilah 38.548007816281995
# Delilah 38.548007816281995
# Delilah 38.72433182598662
# Delilah 38.47593371634002
# Delilah 38.56487561878712
# Delilah 38.91240905274289
# Delilah 38.91240905274289
# Delilah 39.29190312262664
# Delilah 39.2067014950766
# Delilah 39.2067014950766
# Delilah 38.93340029741328
# Delilah 38.91048897318693
# Delilah 38.88758258424629
# Delilah 38.51017712700602
# Delilah 38.51017712700602
# Delilah 38.20235743220747
# Delilah 38.4752604646255
# Delilah 37.913540897485404
# Delilah 38.497587870369756
# Delilah 38.497587870369756
# Delilah 38.09853750770443
# Delilah 38.498427373465525
# Delilah 38.498427373465525
# Delilah 39.028688231181874
# Delilah 38.24051639502048
# Delilah 39.0188011585767
# Delilah 39.0188011585767
# Delilah 38.75591493962961
# Delilah 39.7532846832393
# Delilah 39.7532846832393
# Delilah 40.733070815745656
# Delilah 43.39251746714389
# Delilah 41.088278840650005
# Delilah 39.618090172510705
# Delilah 39.618090172510705
# Delilah 39.891535141165654
# Delilah 40.57649635458913
# Delilah 40.57649635458913
# Delilah 41.88931581112626
# Delilah 41.14208591000657
# Delilah 41.628692827802986
# Delilah 42.95557107701482
# Delilah 42.95557107701482
# Delilah 61.30492740633308
# Delilah 59.19811651313813
# Delilah 58.022947949640944
# Delilah 58.022947949640944
# Delilah 58.877511563483104
# Delilah 43.3739267331656
# Delilah 43.08888467151653
# Delilah 43.08888467151653
# Delilah 42.934157661751485
# Delilah 43.085104023816044
# Delilah 43.085104023816044
# Delilah 59.491696345365646
# Delilah 42.43857434697048
# Delilah 42.43857434697048
# Delilah 43.06071445839944
# Delilah 42.48380565637925
# Delilah 42.049093197693274
# Delilah 42.049093197693274
# Delilah 42.62474551745242
# Delilah 42.78927167149686
# Delilah 42.78927167149686
# Delilah 42.524573712721875
# Delilah 42.652793499324495
# Delilah 42.652793499324495
# Delilah 42.895031029222075
# Delilah 41.84741496767833
# Delilah 41.84741496767833
# Delilah 41.401517700101905
# Delilah 41.9406427333736
# Delilah 59.3063904266027
# Delilah 42.388512636248485
# Delilah 59.450998216790516
# Delilah 42.388512636248485
# Delilah 59.450998216790516
# Delilah 42.127591622620535
# Delilah 41.91419749196404
# Delilah 42.104815332550764
# Delilah 42.18527833045897
# Delilah 60.4777336775309
# Delilah 40.88955930833998
# Delilah 42.54421273896909
# Delilah 60.641942265714334
# Delilah 60.641942265714334
# Delilah 42.54421273896909
# Delilah 41.96663918472514
# Delilah 60.14900182099313
# Delilah 41.433998752894325
# Delilah 60.45458009316661
# Delilah 41.77620491618475
# Delilah 60.08539682408211
# Delilah 42.737283750762
# Delilah 60.69753603611011
# Delilah 42.760432113050975
# Delilah 59.67929431149492
# Delilah 42.23634471437812
# Delilah 59.82246327813803
# Delilah 42.23634471437812
# Delilah 59.82246327813803
# Delilah 42.176909556640304
# Delilah 61.107540383768544
# Delilah 41.57522492468418
# Delilah 41.502389219590945
# Delilah 42.069848996074214
# Delilah 60.68879297138123
# Delilah 42.069848996074214
# Delilah 60.68879297138123
# Delilah 41.646831118230914
# Delilah 41.28156581868305
# Delilah 60.206882908976304
# Delilah 42.05459171948561
# Delilah 59.78346546235457
# Delilah 42.05459171948561
# Delilah 59.78346546235457
# Delilah 41.87033392959417
# Delilah 41.65881312137851
# Delilah 42.505500015491286
# Delilah 42.505500015491286
# Delilah 42.36337262486616
# Delilah 63.19062051732564
# Delilah 63.19062051732564
# Delilah 46.17813176235548
# Delilah 46.71083705113761
# Delilah 46.71083705113761
# Delilah 47.142514099841215
# Delilah 45.164546513730514
# Delilah 45.164546513730514
# Delilah 44.16010215589137
# Delilah 44.16010215589137
# Delilah 41.992918159741365
# Delilah 42.35597464456861
# Delilah 42.77594638463626
# Delilah 42.77594638463626
# Delilah 42.42266444467553
# Delilah 42.655178688273956
# Delilah 41.94279161400373
# Delilah 41.94279161400373
# Delilah 43.020478359611985
# Delilah 42.363781648488214
# Delilah 42.441896931690614
# Delilah 61.99318919441079
# Delilah 43.517317856133076
# Delilah 43.517317856133076
# Delilah 45.090064008389824
# Delilah 46.49563938697682
# Delilah 45.31764859775568
# Delilah 45.31764859775568
# Delilah 45.346704343774725
# Delilah 43.25271188216279
# Delilah 43.25271188216279
# Delilah 43.77258748838216
# Delilah 43.29236415082585
# Delilah 43.15157381130146
# Delilah 43.15157381130146
# Delilah 43.062446047283586
# Delilah 42.377135341387394
# Delilah 42.377135341387394
# Delilah 42.96005285721303
# Delilah 42.887028592805486
# Delilah 42.64523094134327
# Delilah 42.64523094134327
# Delilah 43.404620075796316
# Delilah 41.69050140446336
# Delilah 42.70610260363841
# Delilah 42.70610260363841
# Delilah 43.569237319405495
# Delilah 42.44062268662615
# Delilah 42.44062268662615
# Delilah 44.01214219839571
# Delilah 43.03025899219258
# Delilah 43.883587944812376
# Delilah 43.92497875315541
# Delilah 43.282870109055416
# Delilah 43.282870109055416
# Delilah 43.1498571033646
# Delilah 42.5483657977014
# Delilah 42.833565808369606
# Delilah 43.442748552676946
# Delilah 42.13619610308859
# Delilah 43.53052468824805
# Delilah 43.72402950237965
# Delilah 42.394326294714304
# Delilah 42.394326294714304
# Delilah 43.24127121620921
# Delilah 62.25310148864375
# Delilah 43.24127121620921
# Delilah 62.25310148864375
# Delilah 41.97242632880698
# Delilah 42.700040892210374
# Delilah 42.700040892210374
# Delilah 41.95749175246043
# Delilah 41.95749175246043
# Delilah 40.80802662514426
# Delilah 41.97749822375377
# Delilah 41.47101185795097
# Delilah 41.47101185795097
# Delilah 42.19365020926493
# Delilah 41.63276077427239
# Delilah 41.73221300617766
# Delilah 41.73221300617766
# Delilah 42.192650334966515
# Delilah 41.330553889368225
# Delilah 41.850870798175826
# Delilah 41.850870798175826
# Delilah 41.999496948159226
# Delilah 42.235973224068815
# Delilah 42.321599656041485
# Delilah 42.321599656041485
# Delilah 42.17941298040041
# Delilah 42.57631482617464
# Delilah 42.682181570501996
# Delilah 42.682181570501996
# Delilah 42.37223240066085
# Delilah 42.78068312103407
# Delilah 41.95390216201787
# Delilah 42.37613890547498
# Delilah 42.37613890547498
# Delilah 42.263313679641826
# Delilah 42.634498937513015
# Delilah 42.634498937513015
# Delilah 43.02471529199703
# Delilah 42.402717567804466
# Delilah 42.66536642183085
# Delilah 42.66536642183085
# Delilah 42.54177673689002
# Delilah 42.719251429056236
# Delilah 42.719251429056236
# Delilah 42.40739242309088
# Delilah 42.46431378157308
# Delilah 42.206756856424974
# Delilah 42.206756856424974
# Delilah 42.484163446271026
# Delilah 42.778684489393456
# Delilah 42.17632119256721
# Delilah 42.17632119256721
# Delilah 42.52011033287124
# Delilah 42.331225370330046
# Delilah 41.536181361210765
# Delilah 42.24770016591212
# Delilah 42.24770016591212
# Delilah 41.78781508097859
# Delilah 42.60133390358023
# Delilah 42.60133390358023
# Delilah 42.03838178485751
# Delilah 41.87066924199579
